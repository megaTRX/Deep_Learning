# %% [markdown]
# ##**[9주차]실습**
# - 아래의 실습1), 실습2), 실습3)에서 코드를 완성하시오.
# - colab 사용 시, 빠른 실습 진행을 위해 GPU 사용 설정이 필요합니다. (런타임 유형->T4 GPU 사옹)

# %%
print("2353881, 최대영")
# Out:
# 2353881, 최대영

# %%
from google.colab import auth

auth.authenticate_user()
# !gcloud config get-value account
# Out:
# tigers7101@gmail.com

# %%
# google drive 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install beautifulSoup4
# Out:
# Requirement already satisfied: beautifulSoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulSoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulSoup4) (4.15.0)

# %%
# !pip install finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.110-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from finance-datareader) (4.13.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from finance-datareader) (6.1.0)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from finance-datareader) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from finance-datareader) (5.24.1)
# Collecting requests-file (from finance-datareader)
#   Downloading requests_file-3.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from finance-datareader) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from finance-datareader) (4.67.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.0->finance-datareader) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.0->finance-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.0->finance-datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.0->finance-datareader) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.3.0->finance-datareader) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.3.0->finance-datareader) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.3.0->finance-datareader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.3.0->finance-datareader) (2026.4.22)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->finance-datareader) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->finance-datareader) (4.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->finance-datareader) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly->finance-datareader) (26.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.0->finance-datareader) (1.17.0)
# Downloading finance_datareader-0.9.110-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 2.6 MB/s eta 0:00:00
# Downloading requests_file-3.0.1-py2.py3-none-any.whl (4.5 kB)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.110 requests-file-3.0.1

# %% [markdown]
# ###**예제 1) 데이터를 잘라서 샘플을 작성해본다.**
# - **[실습목표]** 삼성의 실제 주식 데이터를 사용하여 순환신경망의 학습에 사용할 수 있는 샘플을 제작해본다.

# %% [markdown]
# ####**실습 1-1)**
#   - 데이터를 다운로드하고 그래프로 그려본다.

# %%
# 라이브러리 import
import FinanceDataReader as fdr
import numpy as np
import matplotlib.pyplot as plt

# 삼성전자 코드='005930', 2020년부터 '2021-03-08'까지의 데이터 다운로드
'''이곳에 코드를 작성하시오''' # fdr.DataReader 함수 입력 형태 -> fdr.DataReader(삼성전자 코드, 시작기간, 끝기간)
samsung = fdr.DataReader('005930', '2020')

# 삼성전자 데이터세트의 head 출력
print(samsung.head())
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921

# %%
# 시작가만 취한다.
seq_data = (samsung[['Open']]).to_numpy()

# 데이터를 선형 그래프로 그린다.
plt.plot(seq_data, color='blue')
plt.title("Samsung Electronics Stock Price")
plt.xlabel("days")
plt.show()

# %% [markdown]
# ####**실습 1-2)**
#   - 데이터를 잘라서 샘플을 생성해본다.

# %%
# 위에서 load 한 데이터셋으로 학습 데이터셋을 들어 출력한다.
def make_sample(data, window):
    train = []
    target = []
    for i in range(len(data)-window): # 데이터의 길이만큼 반복
      train.append(data[i:i+window]) # iqnxj (i+window-1)까지를 저장
      target.append(data[i+window]) # (i+window) 번째 요소는 정답
    return np.array(train), np.array(target) # 훈련 샘플과 정답 레이블 반환

X, y = make_sample(seq_data, 7) # 윈도우 크기 = 7
print(X.shape, y.shape) # 넘파이 배열의 형상 출력
print(X[0], y[0]) # 첫 번째 샘플 출력
# Out:
# (1546, 7, 1) (1546, 1)
# [[55500]
#  [56000]
#  [54900]
#  [55700]
#  [56200]
#  [58400]
#  [58800]] [59600]

# %% [markdown]
# ###**예제 2) 사인파 예측 프로그램**
# - **[실습목표]** 사인파 정보로 학습 데이터를 생성하고, 생성한 데이터로 학습 및 예측을 수행해본다.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# %%
# 사인파 학습을 위한 데이터세트를 생성한다.
seq_data = []
for i in np.arange(0, 1000):
    seq_data += [[np.sin( np.pi * i * 0.01)]]
X, y = make_sample(seq_data, 10)

# %%
# model을 선언한다.
model = Sequential()
model.add(SimpleRNN(10, activation='tanh', input_shape=(10, 1)))
model.add(Dense(1, activation='tanh'))
model.compile(optimizer='adam', loss='mse')

history = model.fit(X, y, epochs=100, verbose=1)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.2669
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0730
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0323
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0240
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0214
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0198
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0184
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0170
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0154
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0136
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0120
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0105
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0049
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039
# Epoch 32/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038
# Epoch 33/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034
# Epoch 37/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033
# Epoch 39/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032
# Epoch 40/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031
# Epoch 42/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030
# Epoch 43/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029
# Epoch 45/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028
# Epoch 46/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027
# Epoch 48/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026
# Epoch 50/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025
# Epoch 51/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 63/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018
# Epoch 64/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018
# Epoch 65/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 66/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017
# Epoch 67/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017
# Epoch 68/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 69/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 70/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 71/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016
# Epoch 72/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016
# Epoch 73/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015
# Epoch 74/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015
# Epoch 75/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 76/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 77/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014
# Epoch 78/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014
# Epoch 79/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014
# Epoch 80/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 81/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 82/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010

# %%
# loss 그래프를 출력한다.
'''이곳에 코드를 작성하시오'''
plt.plot(history.history['loss'], label="loss")
plt.show()

# %%
# 실제 데이터와 예측한 데이터의 값을 함께 그래프로 출력한다.
y_pred = '''이곳에 코드를 작성하시오'''
'''이곳에 코드를 작성하시오 (예측값 그래프)'''
'''이곳에 코드를 작성하시오 (실제값 그래프)'''
plt.show()

# %% [markdown]
# ###**예제 3) Keras를 이용한 주가 예측**
# - **[실습목표]** 예제 1에서 생성한 것과 같이 삼성의 주가 데이터를 학습데이터로 작성하고, 데이터를 기반으로 주가를 예측하는 모델을 구축한다.

# %%
import FinanceDataReader as fdr
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 2016년 부터 2021년까지의 데이터를 load 한다.
samsung = fdr.DataReader('005930', '2016')
print(samsung)
# Out:
#               Open    High     Low   Close    Volume    Change
# Date
# 2016-01-04   25200   25200   24100   24100    306939 -0.043651
# 2016-01-05   24040   24360   23720   24160    216002  0.002490
# 2016-01-06   24160   24160   23360   23500    366752 -0.027318
# 2016-01-07   23320   23660   23020   23260    282388 -0.010213
# 2016-01-08   23260   23720   23260   23420    257763  0.006879
# ...            ...     ...     ...     ...       ...       ...
# 2026-04-23  223000  229500  216000  224500  34525485  0.032184
# 2026-04-24  224000  225000  216500  219500  19626666 -0.022272
# 2026-04-27  220000  226000  218500  224500  22870374  0.022779
# 2026-04-28  224000  226000  221500  222000  18444490 -0.011136
# 2026-04-29  219500  222000  218500  220250   5699351 -0.007883
#
# [2532 rows x 6 columns]

# %%
# 시작가 만을 openValue에 입력한다.
openValues = samsung[['Open']]

# %%
# 특징값 정규화
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled = scaler.fit_transform(openValues)

# %%
# 훈련 데이터와 테스트 데이터의 분리
TEST_SIZE = 200
train_data = scaled[:-TEST_SIZE]
test_data = scaled[-TEST_SIZE:]

# %%
# 순차 훈련 데이터를 생성한다.
X_train, y_train = make_sample(train_data, 30)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
# LSTM 구축하기
model = Sequential()
model.add(LSTM(16,
               input_shape=(X_train.shape[1], 1),
               activation='tanh',
               return_sequences=False))
model.add(Dense(1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 모델 학습
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(X_train, y_train, epochs = 100, batch_size = 16)
# Out:
# Epoch 1/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0049
# Epoch 2/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.4628e-04
# Epoch 3/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.8169e-04
# Epoch 4/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.7270e-04
# Epoch 5/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.6203e-04
# Epoch 6/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.5966e-04
# Epoch 7/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.5565e-04
# Epoch 8/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.5171e-04
# Epoch 9/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.4791e-04
# Epoch 10/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.4543e-04
# Epoch 11/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.4378e-04
# Epoch 12/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.3682e-04
# Epoch 13/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.3930e-04
# Epoch 14/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.3275e-04
# Epoch 15/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.3284e-04
# Epoch 16/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.2978e-04
# Epoch 17/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.2936e-04
# Epoch 18/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.2671e-04
# Epoch 19/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.2263e-04
# Epoch 20/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.2181e-04
# Epoch 21/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.2295e-04
# Epoch 22/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1919e-04
# Epoch 23/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1867e-04
# Epoch 24/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.2193e-04
# Epoch 25/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1516e-04
# Epoch 26/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1614e-04
# Epoch 27/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1521e-04
# Epoch 28/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1231e-04
# Epoch 29/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0926e-04
# Epoch 30/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1155e-04
# Epoch 31/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0900e-04
# Epoch 32/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0661e-04
# Epoch 33/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0799e-04
# Epoch 34/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0937e-04
# Epoch 35/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0566e-04
# Epoch 36/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0827e-04
# Epoch 37/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0214e-04
# Epoch 38/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0147e-04
# Epoch 39/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0233e-04
# Epoch 40/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0244e-04
# Epoch 41/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0205e-04
# Epoch 42/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0041e-04
# Epoch 43/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.7828e-05
# Epoch 44/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0049e-04
# Epoch 45/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.8367e-05
# Epoch 46/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.4766e-05
# Epoch 47/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.8873e-05
# Epoch 48/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.6162e-05
# Epoch 49/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.1314e-05
# Epoch 50/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.2595e-05
# Epoch 51/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.2111e-05
# Epoch 52/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.4083e-05
# Epoch 53/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.8994e-05
# Epoch 54/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.8581e-05
# Epoch 55/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.4867e-05
# Epoch 56/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.8373e-05
# Epoch 57/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.6815e-05
# Epoch 58/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.6244e-05
# Epoch 59/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.4215e-05
# Epoch 60/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.5322e-05
# Epoch 61/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.6930e-05
# Epoch 62/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.2216e-05
# Epoch 63/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.2073e-05
# Epoch 64/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 8.0187e-05
# Epoch 65/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.8841e-05
# Epoch 66/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 7.7695e-05
# Epoch 67/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 8.1907e-05
# Epoch 68/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.5767e-05
# Epoch 69/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.5242e-05
# Epoch 70/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.9407e-05
# Epoch 71/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.4967e-05
# Epoch 72/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 7.4063e-05
# Epoch 73/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7.2898e-05
# Epoch 74/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.1844e-05
# Epoch 75/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.1080e-05
# Epoch 76/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9099e-05
# Epoch 77/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.6807e-05
# Epoch 78/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.9626e-05
# Epoch 79/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.9244e-05
# Epoch 80/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.0270e-05
# Epoch 81/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.0246e-05
# Epoch 82/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.9320e-05
# Epoch 83/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.6629e-05
# Epoch 84/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 6.8536e-05
# Epoch 85/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.0363e-05
# Epoch 86/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.6922e-05
# Epoch 87/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.5955e-05
# Epoch 88/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.9995e-05
# Epoch 89/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9048e-05
# Epoch 90/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.6451e-05
# Epoch 91/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.6205e-05
# Epoch 92/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.7784e-05
# Epoch 93/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.9429e-05
# Epoch 94/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.5915e-05
# Epoch 95/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.5017e-05
# Epoch 96/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.6141e-05
# Epoch 97/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.6012e-05
# Epoch 98/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.6156e-05
# Epoch 99/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4321e-05
# Epoch 100/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.7095e-05

# %%
# 테스트셋을 이용하여 미래 주가 예측
X_test, y_test = make_sample(test_data, 30)
pred = model.predict(X_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
# 그래프 그리기
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 9))
plt.plot(y_test, label='stock price')
plt.plot(pred, label='predicted stock price')

plt.legend()
plt.show()
